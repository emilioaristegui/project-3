# %%
# dependencies
import pandas as pd
from pprint import pprint

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import inspect
from sqlalchemy.sql import operators, extract

# %%
methane_df = pd.read_csv("data/Methane_final.csv")
coordinates_df = pd.read_csv("data/average-latitude-longitude-countries.csv")
merged_df = methane_df.merge(coordinates_df, on="Country")
merged_df.head(5)
# Out:
#    Unnamed: 0  region  Country   emissions         type  \
# 0           0  Africa  Algeria  257.611206  Agriculture
# 1           1  Africa  Algeria    0.052000       Energy
# 2           2  Africa  Algeria  130.798996       Energy
# 3           3  Africa  Algeria   69.741898       Energy
# 4           4  Africa  Algeria  213.986999       Energy
#
#                             segment    reason   baseYear  \
# 0                             Total       All  2019-2021
# 1                         Bioenergy       All       2022
# 2  Gas pipelines and LNG facilities  Fugitive       2022
# 3  Gas pipelines and LNG facilities    Vented       2022
# 4                       Onshore gas  Fugitive       2022
#
#                                                notes ISO 3166 Country Code  \
# 0  Average based on United Nations Framework Conv...                    DZ
# 1  Estimates from end-uses are for 2020 or 2021 (...                    DZ
# ...

# %%
#Merge both csv files to gather latitude and longitude of the desired countries for mapping on FLASK
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %%
merged_df.to_csv('merged_df.csv')

# %%
merged_df
# Out:
#                 region     Country   emissions         type  \
# 0               Africa     Algeria  257.611206  Agriculture
# 1               Africa     Algeria    0.052000       Energy
# 2               Africa     Algeria  130.798996       Energy
# 3               Africa     Algeria   69.741898       Energy
# 4               Africa     Algeria  213.986999       Energy
# ...                ...         ...         ...          ...
# 1265  Russia & Caspian  Uzbekistan   16.973917       Energy
# 1266  Russia & Caspian  Uzbekistan   18.299999       Energy
# 1267  Russia & Caspian  Uzbekistan  780.916138       Energy
# 1268  Russia & Caspian  Uzbekistan    3.845616        Other
# 1269  Russia & Caspian  Uzbekistan  280.418243        Waste
#
#                                              segment    reason   baseYear  \
# 0                                              Total       All  2019-2021
# 1                                          Bioenergy       All       2022
# ...

# %% [markdown]
# ### Connection between python and SQL

# %%
engine = sqlalchemy.create_engine('postgresql:///data/db.db')

# %%
session = Session(engine)
